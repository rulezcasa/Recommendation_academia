# %%
import pandas as pd
import numpy as np
import bcrypt
from pymongo import MongoClient
import ssl
from sklearn.metrics.pairwise import cosine_similarity
import nltk
import re
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data=pd.read_csv('merged_df.csv')

# %%
data.drop(['Unnamed: 0','_id','password','Timestamp'],axis=1,inplace=True)

# %%
data
# Out:
#                    Name                            Email  profession  \
# 0             Deependar            deependar37@gmail.com     Student
# 1         Devanshi Vora           devanshi.v11@gmail.com     Student
# 2            Hamsini .R        hamsini.ramanan@gmail.com     Student
# 3                 Zenha             zenhaiqbal@gmail.com     Student
# 4                 Jothi            jothithangu@gmail.com     Faculty
# ..                  ...                              ...         ...
# 572         Tyler Rojas       tyler.rojas@university.edu  Researcher
# 573        Sierra Zhang      sierra.zhang@university.edu     Faculty
# 574       Joshua Hughes     joshua.hughes@university.edu  Researcher
# 575     Jeffery Hammond      jeffery.hammond@example.com     Student
# 576  Christopher Wagner  christopher.wagner@research.org     Faculty
#
#                interest                 collaboration  \
# 0              Projects              Student, Faculty
# 1              Projects  Student, Faculty, Researcher
# 2    Projects, Research  Student, Faculty, Researcher
# 3          Study Groups                       Student
# 4              Projects                       Faculty
# ..                  ...                           ...
# 572            Projects                    Researcher
# 573        Study groups                    Researcher
# 574            Projects                    Researcher
# 575            Projects                       Student
# 576        Study groups                       Student
#
#                           Topic  \
# 0                    Structures
# 1                       AI & ML
# 2                           NLP
# 3                    Literature
# 4               Data management
# ..                          ...
# 572        Robotics and Sensors
# 573  Human-Computer Interaction
# 574       Sustainable Computing
# 575               Cybersecurity
# 576     Artificial Intelligence
#
#                                                 Skills  Experience
# 0                                 Structural analysis.         3.0
# 1    Mainly necessary coding languages and web deve...         3.0
# 2                     Data Analytics , AI , Tensorflow         4.0
# 3                       English poetry, prose, fiction         5.0
# 4                                    Mechanical Design        12.0
# ..                                                 ...         ...
# 572  Drug development, bioinformatics with R progra...         3.0
# 573  HTML,ReactJS, DL, ml, dl, app dev, ml, dl, app...        18.0
# 574  Web development\nBioinformatics tools\nMarketi...         5.0
# 575  Software Testing, C, C++, Python, Java, HTML, ...         1.0
# 576  Human-Computer Interaction, Digital design\nFo...        11.0
#
# [577 rows x 8 columns]

# %%
# Disable SSL verification
ssl._create_default_https_context = ssl._create_unverified_context

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/casarulez/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Listing out stopwords in english
x=stopwords.words('english')

# %%
# Download required NLTK data
nltk.download('wordnet')
nltk.download('omw-1.4')

def general_preprocess(to_preprocess_column_name, df_name):
    to_preprocess_column_name_processed = []
    lemma = WordNetLemmatizer()
    
    for i in range(len(df_name)):
        col = df_name.iloc[i][to_preprocess_column_name]
        col = re.sub('[^a-zA-Z]', ' ', col)  # Remove non-alphabetic characters
        col = col.lower()  # Convert to lowercase
        col = col.split()  # Split into words
        col = [lemma.lemmatize(word) for word in col if word not in set(stopwords.words('english'))]  # Lemmatize and remove stopwords
        col = ' '.join(col)  # Join words back into a single string
        to_preprocess_column_name_processed.append(col)
    
    return to_preprocess_column_name_processed
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/casarulez/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/casarulez/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
Topic_preprocessed=general_preprocess('Topic',data)

# %%
Topic_preprocessed
# Out:
# ['structure',
#  'ai ml',
#  'nlp',
#  'literature',
#  'data management',
#  'aiml ui design',
#  'machine learning deep learning',
#  'biotechnology',
#  'machine learning deep learning quantitative analysis',
#  'vlsi microprocessor microcontrollers arduino rtl designing antenna designing communication',
#  'robotics sensor',
#  'data science',
#  'ai ml cloud computing',
#  'cyber security software development cloud application',
#  'probablity theory combinatorics machine learning statistic competitive programming',
#  'machine learning',
#  'electronics robotics',
#  'cybersecurity cloud computing',
#  'ml',
#  'anything',
#  'game',
#  'cricket',
#  'artificial intelligence machine learning',
#  'web development',
#  'strategic management',
#  'artificial intelligence',
#  'hybrid engine anything related mechatronics engineering',
#  'finance technology',
#  'ar vr',
#  'aiml devops mlops web dev',
#  'c',
#  'nlp finance staristical mathematics',
#  'ai',
#  'aws ui ux design',
#  'cyber security ethical hacking',
#  'cyber security',
#  'anything computer science exploring rn',
#  'law',
#  'ai genetics',
#  'social work community engagement development',
#  'behavioural economics',
#  'finance aero data science coding',
#  'proteomic analysis bioassay testing biopharma',
#  'data science sport analytics',
#  'functional safety',
#  'digital system design',
#  'rizz',
#  'ml generative ai',
#  'ai ml',
#  'robotics',
#  'full stack development',
#  'preferably medical related',
#  'robotics',
#  'machine learning',
#  'data science',
#  'cross breed',
#  'data science',
#  'app development',
#  'flutter ai ml',
#  'nlp',
#  'ml',
#  'escape',
#  'computer dsa ml dl nlp',
#  'ml dl nlp',
#  'data science',
#  'nlp',
#  'ai ml nlp',
#  'nlp',
#  'pjt',
#  'web development',
#  'web development',
#  'ml dl mv',
#  'ml ai app dev',
#  'ml dl',
#  'nlp',
#  'nlp',
#  'natural language processing',
#  'digital humanity',
#  'multimedia computing',
#  'ml dl mv',
#  'mobile development',
#  'complex system',
#  'cybersecurity',
#  'aws ui ux design',
#  'ai ml cloud computing',
#  'data management',
#  'ar vr',
#  'blockchain',
#  'ui ux design',
#  'pattern recognition',
#  'data science sport analytics',
#  'agile methodology',
#  'data science',
#  'parallel computing',
#  'cognitive science',
#  'strategic management',
#  'quantum computing',
#  'digital system design',
#  'computer vision',
#  'distributed system',
#  'game development',
#  'game development',
#  'embedded system',
#  'virtual reality',
#  'quantum computing',
#  'bioinformatics',
#  'anything computer science exploring rn',
#  'full stack development',
#  'matlab',
#  'data science',
#  'aiml ui design',
#  'flutter ai ml',
#  'functional safety',
#  'database',
#  'virtual reality',
#  'ml dl mv',
#  'anything',
#  'game',
#  'data science',
#  'artificial intelligence machine learning',
#  'natural language processing',
#  'theoretical computer science',
#  'software architecture',
#  'human computer interaction',
#  'law',
#  'data science',
#  'project management',
#  'data warehousing',
#  'app development',
#  'ai genetics',
#  'machine learning deep learning quantitative analysis',
#  'nlp',
#  'proteomic analysis bioassay testing biopharma',
#  'multimedia computing',
#  'finance technology',
#  'ml generative ai',
#  'virtual reality',
#  'data science',
#  'behavioural economics',
#  'biotechnology',
#  'ai ml',
#  'app development',
#  'cyber security ethical hacking',
#  'nlp',
#  'robotics',
#  'virtual reality',
#  'r',
#  'cyber security ethical hacking',
#  'operating system',
#  'multimedia computing',
#  'finance technology',
#  'app development',
#  'cybersecurity cloud computing',
#  'app development',
#  'nlp',
#  'full stack development',
#  'finance technology',
#  'artificial intelligence machine learning',
#  'ui ux design',
#  'computational neuroscience',
#  'etl process',
#  'structure',
#  'pattern recognition',
#  'robotics',
#  'app development',
#  'vlsi microprocessor microcontrollers arduino rtl designing antenna designing communication',
#  'ml dl',
#  'functional safety',
#  'computational biology',
#  'devops',
#  'computational neuroscience',
#  'rizz',
#  'project management',
#  'database management',
#  'nlp',
#  'hybrid engine anything related mechatronics engineering',
#  'embedded system',
#  'finance aero data science coding',
#  'human computer interaction',
#  'cybersecurity',
#  'database management',
#  'etl process',
#  'html',
#  'strategic management',
#  'software testing',
#  'preferably medical related',
#  'ai ml',
#  'cloud computing',
#  'artificial intelligence machine learning',
#  'social network analysis',
#  'law',
#  'probablity theory combinatorics machine learning statistic competitive programming',
#  'matlab',
#  'cricket',
#  'rizz',
#  'robotics',
#  'data science',
#  'system administration',
#  'algorithm',
#  'ai ml cloud computing',
#  'computer network',
#  'nlp',
#  'vlsi microprocessor microcontrollers arduino rtl designing antenna designing communication',
#  'strategic management',
#  'augmented reality',
#  'ai ml cloud computing',
#  'electronics robotics',
#  'quantum computing',
#  'machine learning deep learning quantitative analysis',
#  'javascript',
#  'natural language processing',
#  'r',
#  'database management',
#  'software architecture',
#  'flutter ai ml',
#  'electronics robotics',
#  'proteomic analysis bioassay testing biopharma',
#  'finance aero data science coding',
#  'pattern recognition',
#  'cybersecurity',
#  'data mining',
#  'parallel computing',
#  'computer network',
#  'augmented reality',
#  'multimedia computing',
#  'nlp',
#  'human computer interaction',
#  'cyber security software development cloud application',
#  'data science',
#  'environmental informatics',
#  'game theory',
#  'cs',
#  'cybersecurity',
#  'iot',
#  'game',
#  'software engineering',
#  'data mining',
#  'proteomic analysis bioassay testing biopharma',
#  'java',
#  'ai',
#  'biotechnology',
#  'business intelligence',
#  'ai ml cloud computing',
#  'quantum computing',
#  'artificial intelligence',
#  'cyber security software development cloud application',
#  'etl process',
#  'r',
#  'information retrieval',
#  'data analysis',
#  'data analysis',
#  'social work community engagement development',
#  'software architecture',
#  'ml dl nlp',
#  'artificial intelligence',
#  'multimedia computing',
#  'behavioural economics',
#  'computer network',
#  'nlp finance staristical mathematics',
#  'ai ml',
#  'game theory',
#  'probablity theory combinatorics machine learning statistic competitive programming',
#  'educational technology',
#  'web development',
#  'computer dsa ml dl nlp',
#  'aiml ui design',
#  'data science',
#  'ml',
#  'anything computer science exploring rn',
#  'matlab',
#  'cognitive science',
#  'java',
#  'ml',
#  'full stack development',
#  'ml dl nlp',
#  'data analysis',
#  'scientific computing',
#  'iot',
#  'sql',
#  'virtual reality',
#  'app development',
#  'vlsi microprocessor microcontrollers arduino rtl designing antenna designing communication',
#  'anything computer science exploring rn',
#  'cybersecurity',
#  'algorithm',
#  'blockchain',
#  'cybersecurity',
#  'bioinformatics',
#  'pattern recognition',
#  'pattern recognition',
#  'digital humanity',
#  'cybersecurity',
#  'r',
#  'web development',
#  'machine learning',
#  'ml generative ai',
#  'educational technology',
#  'computer vision',
#  'computational neuroscience',
#  'functional safety',
#  'scientific computing',
#  'algorithm',
#  'geospatial analysis',
#  'digital humanity',
#  'agile methodology',
#  'etl process',
#  'preferably medical related',
#  'ml ai app dev',
#  'business intelligence',
#  'digital humanity',
#  'project management',
#  'computational neuroscience',
#  'cybersecurity cloud computing',
#  'excel',
#  'augmented reality',
#  'structure',
#  'computational neuroscience',
#  'mobile development',
#  'project management',
#  'machine learning deep learning',
#  'data science',
#  'matlab',
#  'devops',
#  'embedded system',
#  'etl process',
#  'python',
#  'machine learning',
#  'nlp',
#  'game theory',
#  'computational biology',
#  'structure',
#  'database management',
#  'web development',
#  'software architecture',
#  'cloud computing',
#  'machine learning deep learning quantitative analysis',
#  'social work community engagement development',
#  'sql',
#  'machine learning',
#  'agile methodology',
#  'data science',
#  'ml dl',
#  'data science',
#  'web development',
#  'escape',
#  'vlsi microprocessor microcontrollers arduino rtl designing antenna designing communication',
#  'cs',
#  'natural language processing',
#  'computer dsa ml dl nlp',
#  'cross breed',
#  'anything computer science exploring rn',
#  'robotics',
#  'nlp',
#  'networking',
#  'social work community engagement development',
#  'ml dl nlp',
#  'game theory',
#  'natural language processing',
#  'structure',
#  'mobile development',
#  'computer network',
#  'web development',
#  'pjt',
#  'business intelligence',
#  'nlp finance staristical mathematics',
#  'r',
#  'machine learning',
#  'artificial intelligence machine learning',
#  'ml dl',
#  'robotics',
#  'aiml ui design',
#  'full stack development',
#  'networking',
#  'computer vision',
#  'app development',
#  'cybersecurity cloud computing',
#  'complex system',
#  'networking',
#  'algorithm',
#  'information retrieval',
#  'robotics',
#  'ar vr',
#  'big data',
#  'aiml ui design',
#  'web development',
#  'game theory',
#  'networking',
#  'digital humanity',
#  'pjt',
#  'c',
#  'ml generative ai',
#  'behavioural economics',
#  'nlp',
#  'quantum computing',
#  'scientific computing',
#  'nlp finance staristical mathematics',
#  'flutter ai ml',
#  'health informatics',
#  'nlp',
#  'structure',
#  'machine learning',
#  'pattern recognition',
#  'embedded system',
#  'web development',
#  'ai ml',
#  'nlp',
#  'data analysis',
#  'project management',
#  'quantum computing',
#  'nlp finance staristical mathematics',
#  'ml',
#  'ai',
#  'machine learning deep learning quantitative analysis',
#  'flutter ai ml',
#  'ai',
#  'pattern recognition',
#  'web development',
#  'preferably medical related',
#  'behavioural economics',
#  'machine learning deep learning',
#  'web development',
#  'aiml ui design',
#  'ml',
#  'machine learning deep learning quantitative analysis',
#  'quantum computing',
#  'functional safety',
#  'javascript',
#  'system administration',
#  'sql',
#  'cyber security',
#  'nlp',
#  'project management',
#  'cyber security',
#  'rizz',
#  'software engineering',
#  'ar vr',
#  'cyber security software development cloud application',
#  'flutter ai ml',
#  'strategic management',
#  'electronics robotics',
#  'ml dl',
#  'project management',
#  'cs',
#  'software testing',
#  'robotics',
#  'game development',
#  'computer network',
#  'blockchain',
#  'nlp',
#  'computer vision',
#  'data science sport analytics',
#  'ai ml',
#  'e commerce technology',
#  'aws ui ux design',
#  'data science',
#  'biotechnology',
#  'data science',
#  'quantum computing',
#  'aiml devops mlops web dev',
#  'data analysis',
#  'ml ai app dev',
#  'preferably medical related',
#  'nlp',
#  'electronics robotics',
#  'data analysis',
#  'probablity theory combinatorics machine learning statistic competitive programming',
#  'sustainable computing',
#  'functional safety',
#  'mobile development',
#  'nlp',
#  'ml dl',
#  'nlp',
#  'ai ml',
#  'complex system',
#  'ml dl mv',
#  'networking',
#  'nlp',
#  'data warehousing',
#  'ai ml',
#  'environmental informatics',
#  'flutter ai ml',
#  'cybersecurity cloud computing',
#  'cyber security ethical hacking',
#  'database',
#  'computer network',
#  'distributed system',
#  'ai',
#  'complex system',
#  'ai genetics',
#  'robotics sensor',
#  'ml generative ai',
#  'aiml devops mlops web dev',
#  'ml dl',
#  'computer vision',
#  'pattern recognition',
#  'electronics robotics',
#  'ai ml',
#  'software architecture',
#  'ai',
#  'nlp',
#  'nlp finance staristical mathematics',
#  'c',
#  'robotics',
#  'nlp',
#  'iot',
#  'quantum computing',
#  'ai genetics',
#  'cybersecurity',
#  'software testing',
#  'python',
#  'nlp',
#  'web development',
#  'environmental informatics',
#  'cybersecurity cloud computing',
#  'machine learning',
#  'digital humanity',
#  'natural language processing',
#  'c',
#  'proteomic analysis bioassay testing biopharma',
#  'virtual reality',
#  'system administration',
#  'structure',
#  'game development',
#  'social work community engagement development',
#  'data warehousing',
#  'robotics',
#  'behavioural economics',
#  'excel',
#  'software engineering',
#  'c',
#  'digital system design',
#  'ml',
#  'ml ai app dev',
#  'proteomic analysis bioassay testing biopharma',
#  'game theory',
#  'virtual reality',
#  'health informatics',
#  'cybersecurity',
#  'database management',
#  'artificial intelligence',
#  'rizz',
#  'matlab',
#  'big data',
#  'information retrieval',
#  'project management',
#  'bioinformatics',
#  'natural language processing',
#  'machine learning',
#  'behavioural economics',
#  'computer vision',
#  'ai ml nlp',
#  'cloud computing',
#  'parallel computing',
#  'cross breed',
#  'nlp',
#  'data warehousing',
#  'biotechnology',
#  'matlab',
#  'complex system',
#  'robotics',
#  'web development',
#  'web development',
#  'digital system design',
#  'robotics',
#  'artificial intelligence',
#  'quantum computing',
#  'probablity theory combinatorics machine learning statistic competitive programming',
#  'proteomic analysis bioassay testing biopharma',
#  'wireless network',
#  'proteomic analysis bioassay testing biopharma',
#  'computational neuroscience',
#  'c',
#  'robotics sensor',
#  'human computer interaction',
#  'sustainable computing',
#  'cybersecurity',
#  'artificial intelligence']

# %%
Skills_preprocessed=general_preprocess('Skills',data)

# %%
Skills_preprocessed
# Out:
# ['structural analysis',
#  'mainly necessary coding language web development',
#  'data analytics ai tensorflow',
#  'english poetry prose fiction',
#  'mechanical design',
#  'ui',
#  'machine learning neural network enterpreneurship communication',
#  'sport analysis basic genomics knowledge',
#  'ml dl python c c java statistic vector',
#  'verilog coding arduino coding coding',
#  'arduino ide ro fusion',
#  'data management large industry',
#  'java python c c html cs',
#  'internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization',
#  'probability combinatorics python',
#  'ml data analysis',
#  'iot pcb designing arduino programming basic linux',
#  'skilled',
#  'cloud computing',
#  'verbal marketing',
#  'c',
#  'law',
#  'artificial intelligence research basic computer science student',
#  'front end dev basic ui ux design basic back end knowledge',
#  'accountancy fm sm',
#  'android developer',
#  'design problem solving extensive research',
#  'accounting finance commerce basic computer application',
#  'fullstack development plc programming arduino',
#  'web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql aiml ml dl cnn rnn lstm programming java c python',
#  'data analysis',
#  'nlp risk analysis llm',
#  'machine learning',
#  'c c python java html cs sql aws figma flutterflow canva adobe xd',
#  'cyber security coding python',
#  'cyber security coding python',
#  'programming web development app development data science testing',
#  'legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail',
#  'dont posse technical knowledge enticed topic read come across',
#  'awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour skill set empathy listening skill basic data collection analysis interpretation skill',
#  'ty ba economics student',
#  'idea know like basic everything',
#  'drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology',
#  'python sql tableau data analytics',
#  'digital design formal verification',
#  'tanner tool vivado matlab python etc',
#  'nada',
#  'business domain education utility water electricity retail car manufacturing technical domain system design aws azure web mobile development backend development api microservices database ai quantum computing programming skillset c python react j code tool like bubble io mysql postgres mongo db',
#  'python machine learning',
#  'web development bioinformatics tool marketing strategy game design',
#  'mern stack spring boot java',
#  'smart',
#  'rpa',
#  'python programming data analysis',
#  'ai ml dl',
#  'expert',
#  'ai ml',
#  'flutter swift firebase',
#  'flutter swift kotlin',
#  'nlp',
#  'nothing',
#  'escape',
#  'ml dl app dev',
#  'ml dl app dev',
#  'ai ml dl',
#  'data science ai ml',
#  'flask data science',
#  'ai ml data science',
#  'flask',
#  'html cs j ml',
#  'html reactjs dl',
#  'dsa frontend communication',
#  'dsa frontend',
#  'dsa frontend',
#  'python nltk spacy',
#  'spacy nltk python',
#  'spacy python',
#  'dont posse technical knowledge enticed topic read come across design problem solving extensive research design problem solving extensive research design problem solving extensive research',
#  'quantum computing legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail',
#  'software architecture english poetry prose fiction english poetry prose fiction english poetry prose fiction',
#  'data warehousing sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge',
#  'data analysis structural analysis structural analysis structural analysis',
#  'excel iot iot iot',
#  'game development database database database',
#  'robotics big data big data big data',
#  'ai ml dl game development game development game development',
#  'machine learning python machine learning n python machine learning n python machine learning n',
#  'health informatics robotics robotics robotics',
#  'ml dl python c c java statistic vector software engineering software engineering software engineering',
#  'game development embedded system embedded system embedded system',
#  'spacy python data analysis data analysis data analysis',
#  'sql machine learning neural network enterpreneurship communication machine learning neural network enterpreneurship communication machine learning neural network enterpreneurship communication',
#  'mern stack spring boot java cloud computing cloud computing cloud computing',
#  'html reactjs dl cybersecurity cybersecurity cybersecurity',
#  'skilled ai ml data science ai ml data science ai ml data science',
#  'excel cognitive science cognitive science cognitive science',
#  'iot operating system operating system operating system',
#  'web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python theoretical computer science theoretical computer science theoretical computer science',
#  'artificial intelligence research basic computer science student dsa frontend dsa frontend dsa frontend',
#  'machine learning database database database',
#  'data analytics ai tensorflow social network analysis social network analysis social network analysis',
#  'flask data science python nltk spacy python nltk spacy python nltk spacy',
#  'iot sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge',
#  'web development nbioinformatics tool nmarketing strategy ngame design big data big data big data',
#  'java python c c html cs data analysis data analysis data analysis',
#  'structural analysis ai ml dl ai ml dl ai ml dl',
#  'database management data analytics ai tensorflow data analytics ai tensorflow data analytics ai tensorflow',
#  'ml data analysis embedded system embedded system embedded system',
#  'etl process html html html',
#  'ui javascript javascript javascript',
#  'cybersecurity nada nada nada',
#  'agile methodology dont posse technical knowledge enticed topic read come across dont posse technical knowledge enticed topic read come across dont posse technical knowledge enticed topic read come across',
#  'python nltk spacy android developer android developer android developer',
#  'distributed system game development game development game development',
#  'bioinformatics sustainable computing sustainable computing sustainable computing',
#  'python distributed system distributed system distributed system',
#  'cs embedded system embedded system embedded system',
#  'data analysis flutter swift kotlin flutter swift kotlin flutter swift kotlin',
#  'excel smart smart smart',
#  'dsa frontend software testing software testing software testing',
#  'cybersecurity machine learning neural network enterpreneurship communication machine learning neural network enterpreneurship communication machine learning neural network enterpreneurship communication',
#  'dsa frontend python programming data analysis python programming data analysis python programming data analysis',
#  'cyber security coding python dont posse technical knowledge enticed topic read come across dont posse technical knowledge enticed topic read come across dont posse technical knowledge enticed topic read come across',
#  'information retrieval web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python',
#  'blockchain android developer android developer android developer',
#  'legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail quantum computing quantum computing quantum computing',
#  'business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db cybersecurity cybersecurity cybersecurity',
#  'iot mainly necessary coding language web development mainly necessary coding language web development mainly necessary coding language web development',
#  'database environmental informatics environmental informatics environmental informatics',
#  'scientific computing quantum computing quantum computing quantum computing',
#  'web development blockchain blockchain blockchain',
#  'cyber security coding python flutter swift firebase flutter swift firebase flutter swift firebase',
#  'skilled cyber security coding python cyber security coding python cyber security coding python',
#  'database management sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge',
#  'c html html html',
#  'dsa frontend sql sql sql',
#  'nada mobile development mobile development mobile development',
#  'c c c c',
#  'data warehousing ai ai ai',
#  'excel data analysis data analysis data analysis',
#  'ui environmental informatics environmental informatics environmental informatics',
#  'java iot iot iot',
#  'nlp risk analysis llm project management project management project management',
#  'computational neuroscience flutter swift firebase flutter swift firebase flutter swift firebase',
#  'mechanical design human computer interaction human computer interaction human computer interaction',
#  'mern stack spring boot java ml dl app dev ml dl app dev ml dl app dev',
#  'information retrieval operating system operating system operating system',
#  'ai ml data science cloud computing cloud computing cloud computing',
#  'r networking networking networking',
#  'complex system ai ml dl ai ml dl ai ml dl',
#  'ai ml dl front end dev nbasic ui ux design nbasic back end knowledge front end dev nbasic ui ux design nbasic back end knowledge front end dev nbasic ui ux design nbasic back end knowledge',
#  'spacy nltk python python programming data analysis python programming data analysis python programming data analysis',
#  'spacy nltk python legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail',
#  'big data data science data science data science',
#  'python ai ml dl ai ml dl ai ml dl',
#  'dsa frontend communication ai ml dl ai ml dl ai ml dl',
#  'ai ml data science data science data science data science',
#  'mern stack spring boot java data management large industry data management large industry data management large industry',
#  'flutter swift kotlin cognitive science cognitive science cognitive science',
#  'internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization dsa frontend dsa frontend dsa frontend',
#  'machine learning law law law',
#  'digital design nformal verification data analysis data analysis data analysis',
#  'cognitive science java python c c html cs java python c c html cs java python c c html cs',
#  'scientific computing scientific computing scientific computing scientific computing',
#  'spacy nltk python social network analysis social network analysis social network analysis',
#  'expert digital humanity digital humanity digital humanity',
#  'ml dl app dev sql sql sql',
#  'iot mobile development mobile development mobile development',
#  'robotics pattern recognition pattern recognition pattern recognition',
#  'ml dl python c c java statistic vector scientific computing scientific computing scientific computing',
#  'big data machine learning machine learning machine learning',
#  'etl process android developer android developer android developer',
#  'java python c c html cs data management large industry data management large industry data management large industry',
#  'machine learning cyber security coding python cyber security coding python cyber security coding python',
#  'mobile development embedded system embedded system embedded system',
#  'computer network flutter swift kotlin flutter swift kotlin flutter swift kotlin',
#  'design problem solving extensive research escape escape escape',
#  'flask data science ui ux design ui ux design ui ux design',
#  'agile methodology data mining data mining data mining',
#  'ai data warehousing data warehousing data warehousing',
#  'html cs j ml ml data analysis ml data analysis ml data analysis',
#  'digital design nformal verification theoretical computer science theoretical computer science theoretical computer science',
#  'networking software engineering software engineering software engineering',
#  'computer vision ty ba economics student ty ba economics student ty ba economics student',
#  'computational neuroscience html cs j ml html cs j ml html cs j ml',
#  'skilled drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology',
#  'scientific computing cloud computing cloud computing cloud computing',
#  'mechanical design mechanical design mechanical design mechanical design',
#  'matlab iot pcb designing arduino programming basic linux iot pcb designing arduino programming basic linux iot pcb designing arduino programming basic linux',
#  'operating system health informatics health informatics health informatics',
#  'data analysis ui ui ui',
#  'distributed system blockchain blockchain blockchain',
#  'computer vision sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge',
#  'spacy python legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail',
#  'geospatial analysis ai ml dl ai ml dl ai ml dl',
#  'ai ml data science spacy nltk python spacy nltk python spacy nltk python',
#  'educational technology arduino ide ro fusion arduino ide ro fusion arduino ide ro fusion',
#  'agile methodology database database database',
#  'dsa frontend communication expert expert expert',
#  'spacy nltk python ai ml ai ml ai ml',
#  'nlp risk analysis llm dsa frontend communication dsa frontend communication dsa frontend communication',
#  'pattern recognition ai ai ai',
#  'cognitive science machine learning machine learning machine learning',
#  'python data warehousing data warehousing data warehousing',
#  'project management data science data science data science',
#  'software testing law law law',
#  'pattern recognition python programming data analysis python programming data analysis python programming data analysis',
#  'sport analysis nbasic genomics knowledge complex system complex system complex system',
#  'devops structural analysis structural analysis structural analysis',
#  'computational neuroscience tanner tool vivado matlab python etc tanner tool vivado matlab python etc tanner tool vivado matlab python etc',
#  'nlp machine learning machine learning machine learning',
#  'dsa frontend communication verilog coding arduino coding coding verilog coding arduino coding coding verilog coding arduino coding coding',
#  'awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill quantum computing quantum computing quantum computing',
#  'e commerce technology virtual reality virtual reality virtual reality',
#  'ui computer vision computer vision computer vision',
#  'information retrieval networking networking networking',
#  'mechanical design data management large industry data management large industry data management large industry',
#  'information retrieval java python c c html cs java python c c html cs java python c c html cs',
#  'web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python ai ml ai ml ai ml',
#  'database management android developer android developer android developer',
#  'scientific computing html cs j ml html cs j ml html cs j ml',
#  'computer network digital design nformal verification digital design nformal verification digital design nformal verification',
#  'fullstack development plc programming arduino mern stack spring boot java mern stack spring boot java mern stack spring boot java',
#  'e commerce technology computer network computer network computer network',
#  'structural analysis python sql tableau data analytics python sql tableau data analytics python sql tableau data analytics',
#  'web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python cyber security coding python cyber security coding python cyber security coding python',
#  'social network analysis computer network computer network computer network',
#  'quantum computing html cs j ml html cs j ml html cs j ml',
#  'sustainable computing flask data science flask data science flask data science',
#  'web development nbioinformatics tool nmarketing strategy ngame design computational neuroscience computational neuroscience computational neuroscience',
#  'blockchain flask data science flask data science flask data science',
#  'algorithm health informatics health informatics health informatics',
#  'virtual reality spacy python spacy python spacy python',
#  'matlab networking networking networking',
#  'business intelligence cybersecurity cybersecurity cybersecurity',
#  'artificial intelligence research basic computer science student law law law',
#  'excel data analytics ai tensorflow data analytics ai tensorflow data analytics ai tensorflow',
#  'html cs j ml computer vision computer vision computer vision',
#  'business intelligence business intelligence business intelligence business intelligence',
#  'information retrieval digital humanity digital humanity digital humanity',
#  'javascript cybersecurity cybersecurity cybersecurity',
#  'machine learning html reactjs dl html reactjs dl html reactjs dl',
#  'excel ai ml ai ml ai ml',
#  'html cs j ml web development web development web development',
#  'flutter swift kotlin excel excel excel',
#  'computer network ai ml ai ml ai ml',
#  'sql machine learning machine learning machine learning',
#  'nlp rpa rpa rpa',
#  'ai ml dl machine learning machine learning machine learning',
#  'web development virtual reality virtual reality virtual reality',
#  'dont posse technical knowledge enticed topic read come across social network analysis social network analysis social network analysis',
#  'computational neuroscience software testing software testing software testing',
#  'digital design nformal verification complex system complex system complex system',
#  'software testing web development nbioinformatics tool nmarketing strategy ngame design web development nbioinformatics tool nmarketing strategy ngame design web development nbioinformatics tool nmarketing strategy ngame design',
#  'excel wireless network wireless network wireless network',
#  'front end dev nbasic ui ux design nbasic back end knowledge r r r',
#  'computer network excel excel excel',
#  'python nltk spacy nlp risk analysis llm nlp risk analysis llm nlp risk analysis llm',
#  'python machine learning n r r r',
#  'complex system ui ui ui',
#  'dsa frontend data science ai ml data science ai ml data science ai ml',
#  'ml dl app dev health informatics health informatics health informatics',
#  'python programming data analysis theoretical computer science theoretical computer science theoretical computer science',
#  'cyber security coding python web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python',
#  'html reactjs dl quantum computing quantum computing quantum computing',
#  'javascript nlp risk analysis llm nlp risk analysis llm nlp risk analysis llm',
#  'data mining database management database management database management',
#  'machine learning machine learning machine learning machine learning',
#  'computer network arduino ide ro fusion arduino ide ro fusion arduino ide ro fusion',
#  'quantum computing bioinformatics bioinformatics bioinformatics',
#  'cs awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill',
#  'dsa frontend communication computer network computer network computer network',
#  'complex system nothing nothing nothing',
#  'accountancy nfm nsm agile methodology agile methodology agile methodology',
#  'cognitive science dsa frontend communication dsa frontend communication dsa frontend communication',
#  'r augmented reality augmented reality augmented reality',
#  'health informatics data analytics ai tensorflow data analytics ai tensorflow data analytics ai tensorflow',
#  'dsa frontend wireless network wireless network wireless network',
#  'ty ba economics student sql sql sql',
#  'natural language processing design problem solving extensive research design problem solving extensive research design problem solving extensive research',
#  'cloud computing nothing nothing nothing',
#  'iot pcb designing arduino programming basic linux multimedia computing multimedia computing multimedia computing',
#  'theoretical computer science devops devops devops',
#  'data analysis rpa rpa rpa',
#  'artificial intelligence research basic computer science student natural language processing natural language processing natural language processing',
#  'data analysis natural language processing natural language processing natural language processing',
#  'spacy python database management database management database management',
#  'python nltk spacy nada nada nada',
#  'artificial intelligence research basic computer science student web development web development web development',
#  'iot pcb designing arduino programming basic linux algorithm algorithm algorithm',
#  'data analytics ai tensorflow java java java',
#  'data science ai ml ui ui ui',
#  'probability combinatorics python python sql tableau data analytics python sql tableau data analytics python sql tableau data analytics',
#  'information retrieval probability combinatorics python probability combinatorics python probability combinatorics python',
#  'matlab theoretical computer science theoretical computer science theoretical computer science',
#  'software testing mern stack spring boot java mern stack spring boot java mern stack spring boot java',
#  'nada mainly necessary coding language web development mainly necessary coding language web development mainly necessary coding language web development',
#  'mobile development mobile development mobile development mobile development',
#  'smart distributed system distributed system distributed system',
#  'software testing sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge',
#  'data analytics ai tensorflow probability combinatorics python probability combinatorics python probability combinatorics python',
#  'cognitive science agile methodology agile methodology agile methodology',
#  'complex system sql sql sql',
#  'natural language processing escape escape escape',
#  'sustainable computing flutter swift kotlin flutter swift kotlin flutter swift kotlin',
#  'quantum computing robotics robotics robotics',
#  'android developer java java java',
#  'artificial intelligence research basic computer science student machine learning machine learning machine learning',
#  'cloud computing nlp nlp nlp',
#  'python virtual reality virtual reality virtual reality',
#  'ui ux design blockchain blockchain blockchain',
#  'networking machine learning machine learning machine learning',
#  'game theory machine learning neural network enterpreneurship communication machine learning neural network enterpreneurship communication machine learning neural network enterpreneurship communication',
#  'arduino ide ro fusion database management database management database management',
#  'html cs j ml parallel computing parallel computing parallel computing',
#  'c arduino ide ro fusion arduino ide ro fusion arduino ide ro fusion',
#  'game theory mern stack spring boot java mern stack spring boot java mern stack spring boot java',
#  'natural language processing quantum computing quantum computing quantum computing',
#  'dsa frontend quantum computing quantum computing quantum computing',
#  'mobile development computer vision computer vision computer vision',
#  'design problem solving extensive research devops devops devops',
#  'parallel computing data mining data mining data mining',
#  'drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology devops devops devops',
#  'dont posse technical knowledge enticed topic read come across artificial intelligence research basic computer science student artificial intelligence research basic computer science student artificial intelligence research basic computer science student',
#  'python machine learning n probability combinatorics python probability combinatorics python probability combinatorics python',
#  'cognitive science dsa frontend dsa frontend dsa frontend',
#  'dsa frontend communication nlp risk analysis llm nlp risk analysis llm nlp risk analysis llm',
#  'data analytics ai tensorflow english poetry prose fiction english poetry prose fiction english poetry prose fiction',
#  'sport analysis nbasic genomics knowledge ai ml dl ai ml dl ai ml dl',
#  'law c c c',
#  'nothing wireless network wireless network wireless network',
#  'blockchain ml dl app dev ml dl app dev ml dl app dev',
#  'bioinformatics machine learning machine learning machine learning',
#  'augmented reality game development game development game development',
#  'networking internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization',
#  'data analysis dsa frontend dsa frontend dsa frontend',
#  'social network analysis business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db',
#  'business intelligence flask data science flask data science flask data science',
#  'matlab data warehousing data warehousing data warehousing',
#  'operating system legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail',
#  'business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db networking networking networking',
#  'skilled digital design nformal verification digital design nformal verification digital design nformal verification',
#  'idea know like basic everything python sql tableau data analytics python sql tableau data analytics python sql tableau data analytics',
#  'nlp ty ba economics student ty ba economics student ty ba economics student',
#  'database management ai ml ai ml ai ml',
#  'excel networking networking networking',
#  'android developer legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail',
#  'escape spacy python spacy python spacy python',
#  'tanner tool vivado matlab python etc environmental informatics environmental informatics environmental informatics',
#  'programming web development app development data science testing data mining data mining data mining',
#  'quantum computing data analytics ai tensorflow data analytics ai tensorflow data analytics ai tensorflow',
#  'data management large industry geospatial analysis geospatial analysis geospatial analysis',
#  'mainly necessary coding language web development html html html',
#  'game theory html reactjs dl html reactjs dl html reactjs dl',
#  'english poetry prose fiction virtual reality virtual reality virtual reality',
#  'flask data science health informatics health informatics health informatics',
#  'ai ml c c c',
#  'ai ml skilled skilled skilled',
#  'html robotics robotics robotics',
#  'mern stack spring boot java excel excel excel',
#  'web development nbioinformatics tool nmarketing strategy ngame design idea know like basic everything idea know like basic everything idea know like basic everything',
#  'iot pcb designing arduino programming basic linux complex system complex system complex system',
#  'sql ui ui ui',
#  'cybersecurity digital design nformal verification digital design nformal verification digital design nformal verification',
#  'design problem solving extensive research data analytics ai tensorflow data analytics ai tensorflow data analytics ai tensorflow',
#  'design problem solving extensive research artificial intelligence research basic computer science student artificial intelligence research basic computer science student artificial intelligence research basic computer science student',
#  'cyber security coding python sustainable computing sustainable computing sustainable computing',
#  'arduino ide ro fusion natural language processing natural language processing natural language processing',
#  'android developer drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology',
#  'dsa frontend communication idea know like basic everything idea know like basic everything idea know like basic everything',
#  'e commerce technology html html html',
#  'bioinformatics python programming data analysis python programming data analysis python programming data analysis',
#  'verilog coding arduino coding coding drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology',
#  'complex system embedded system embedded system embedded system',
#  'human computer interaction smart smart smart',
#  'database management nada nada nada',
#  'business intelligence data management large industry data management large industry data management large industry',
#  'social network analysis verilog coding arduino coding coding verilog coding arduino coding coding verilog coding arduino coding coding',
#  'database management expert expert expert',
#  'scientific computing python python python',
#  'machine learning tanner tool vivado matlab python etc tanner tool vivado matlab python etc tanner tool vivado matlab python etc',
#  'escape educational technology educational technology educational technology',
#  'iot law law law',
#  'mechanical design flask flask flask',
#  'java data warehousing data warehousing data warehousing',
#  'flutter swift firebase escape escape escape',
#  'verbal marketing python nltk spacy python nltk spacy python nltk spacy',
#  'python programming data analysis flutter swift firebase flutter swift firebase flutter swift firebase',
#  'natural language processing ml dl python c c java statistic vector ml dl python c c java statistic vector ml dl python c c java statistic vector',
#  'python dsa frontend dsa frontend dsa frontend',
#  'dsa frontend communication quantum computing quantum computing quantum computing',
#  'arduino ide ro fusion spacy nltk python spacy nltk python spacy nltk python',
#  'cloud computing dsa frontend communication dsa frontend communication dsa frontend communication',
#  'ui ux design dsa frontend dsa frontend dsa frontend',
#  'rpa c c c',
#  'skilled educational technology educational technology educational technology',
#  'project management augmented reality augmented reality augmented reality',
#  'idea know like basic everything mobile development mobile development mobile development',
#  'digital design nformal verification html cs j ml html cs j ml html cs j ml',
#  'scientific computing python programming data analysis python programming data analysis python programming data analysis',
#  'spacy nltk python bioinformatics bioinformatics bioinformatics',
#  'arduino ide ro fusion system administration system administration system administration',
#  'web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python c c c',
#  'front end dev nbasic ui ux design nbasic back end knowledge bioinformatics bioinformatics bioinformatics',
#  'c internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization',
#  'programming web development app development data science testing web development web development web development',
#  'ai ml ml data analysis ml data analysis ml data analysis',
#  'theoretical computer science nlp nlp nlp',
#  'geospatial analysis cloud computing cloud computing cloud computing',
#  'database robotics robotics robotics',
#  'c c python java html cs sql aws figma flutterflow canva adobe xd data warehousing data warehousing data warehousing',
#  'bioinformatics machine learning machine learning machine learning',
#  'parallel computing sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge sport analysis nbasic genomics knowledge',
#  'sport analysis nbasic genomics knowledge flask data science flask data science flask data science',
#  'fullstack development plc programming arduino html cs j ml html cs j ml html cs j ml',
#  'expert game development game development game development',
#  'database database management database management database management',
#  'matlab artificial intelligence research basic computer science student artificial intelligence research basic computer science student artificial intelligence research basic computer science student',
#  'etl process machine learning machine learning machine learning',
#  'c c python java html cs sql aws figma flutterflow canva adobe xd verilog coding arduino coding coding verilog coding arduino coding coding verilog coding arduino coding coding',
#  'blockchain theoretical computer science theoretical computer science theoretical computer science',
#  'web dev html cs j react j typescript tailwind trpc mongodb dynamodb sql naiml ml dl cnn rnn lstm nprogramming java c python information retrieval information retrieval information retrieval',
#  'iot pcb designing arduino programming basic linux quantum computing quantum computing quantum computing',
#  'data science digital humanity digital humanity digital humanity',
#  'flutter swift kotlin matlab matlab matlab',
#  'social network analysis cyber security coding python cyber security coding python cyber security coding python',
#  'nlp smart smart smart',
#  'business intelligence dsa frontend dsa frontend dsa frontend',
#  'quantum computing wireless network wireless network wireless network',
#  'database sustainable computing sustainable computing sustainable computing',
#  'cybersecurity iot iot iot',
#  'flask cyber security coding python cyber security coding python cyber security coding python',
#  'matlab web development nbioinformatics tool nmarketing strategy ngame design web development nbioinformatics tool nmarketing strategy ngame design web development nbioinformatics tool nmarketing strategy ngame design',
#  'cognitive science mobile development mobile development mobile development',
#  'accounting finance commerce basic computer application design problem solving extensive research design problem solving extensive research design problem solving extensive research',
#  'system administration educational technology educational technology educational technology',
#  'health informatics iot pcb designing arduino programming basic linux iot pcb designing arduino programming basic linux iot pcb designing arduino programming basic linux',
#  'ml dl app dev web development nbioinformatics tool nmarketing strategy ngame design web development nbioinformatics tool nmarketing strategy ngame design web development nbioinformatics tool nmarketing strategy ngame design',
#  'verbal marketing health informatics health informatics health informatics',
#  'cyber security coding python dsa frontend communication dsa frontend communication dsa frontend communication',
#  'geospatial analysis verbal marketing verbal marketing verbal marketing',
#  'robotics machine learning neural network enterpreneurship communication machine learning neural network enterpreneurship communication machine learning neural network enterpreneurship communication',
#  'scientific computing cyber security coding python cyber security coding python cyber security coding python',
#  'cognitive science cloud computing cloud computing cloud computing',
#  'ai ml ai ai ai',
#  'flask ai ml dl ai ml dl ai ml dl',
#  'software testing quantum computing quantum computing quantum computing',
#  'database spacy python spacy python spacy python',
#  'devops agile methodology agile methodology agile methodology',
#  'ml dl app dev flutter swift firebase flutter swift firebase flutter swift firebase',
#  'c c python java html cs sql aws figma flutterflow canva adobe xd game development game development game development',
#  'flutter swift kotlin mern stack spring boot java mern stack spring boot java mern stack spring boot java',
#  'machine learning neural network enterpreneurship communication digital design nformal verification digital design nformal verification digital design nformal verification',
#  'ai ml dl accounting finance commerce basic computer application accounting finance commerce basic computer application accounting finance commerce basic computer application',
#  'computer network e commerce technology e commerce technology e commerce technology',
#  'flutter swift kotlin awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill',
#  'machine learning neural network enterpreneurship communication cybersecurity cybersecurity cybersecurity',
#  'ai ml dl quantum computing quantum computing quantum computing',
#  'ml dl python c c java statistic vector mern stack spring boot java mern stack spring boot java mern stack spring boot java',
#  'pattern recognition fullstack development plc programming arduino fullstack development plc programming arduino fullstack development plc programming arduino',
#  'accounting finance commerce basic computer application accountancy nfm nsm accountancy nfm nsm accountancy nfm nsm',
#  'web development nbioinformatics tool nmarketing strategy ngame design etl process etl process etl process',
#  'parallel computing html reactjs dl html reactjs dl html reactjs dl',
#  'cybersecurity multimedia computing multimedia computing multimedia computing',
#  'mechanical design design problem solving extensive research design problem solving extensive research design problem solving extensive research',
#  'data management large industry complex system complex system complex system',
#  'augmented reality ml dl python c c java statistic vector ml dl python c c java statistic vector ml dl python c c java statistic vector',
#  'structural analysis rpa rpa rpa',
#  'business intelligence python sql tableau data analytics python sql tableau data analytics python sql tableau data analytics',
#  'spacy python legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail legal knowledge encompasses vast array topic area specialization internship got opportunity work case related constitutional law criminal law civil law family law corporate law also wide range skill including research skill communication skill critical thinking negotiation skill attention detail',
#  'python sql tableau data analytics bioinformatics bioinformatics bioinformatics',
#  'mechanical design wireless network wireless network wireless network',
#  'multimedia computing agile methodology agile methodology agile methodology',
#  'matlab spacy python spacy python spacy python',
#  'cognitive science cybersecurity cybersecurity cybersecurity',
#  'ml dl python c c java statistic vector software testing software testing software testing',
#  'dsa frontend environmental informatics environmental informatics environmental informatics',
#  'ui business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db',
#  'quantum computing flask flask flask',
#  'blockchain multimedia computing multimedia computing multimedia computing',
#  'game theory database management database management database management',
#  'multimedia computing nothing nothing nothing',
#  'data warehousing python nltk spacy python nltk spacy python nltk spacy',
#  'web development nbioinformatics tool nmarketing strategy ngame design agile methodology agile methodology agile methodology',
#  'operating system front end dev nbasic ui ux design nbasic back end knowledge front end dev nbasic ui ux design nbasic back end knowledge front end dev nbasic ui ux design nbasic back end knowledge',
#  'flask flask flask flask',
#  'skilled expert expert expert',
#  'ml dl app dev computer network computer network computer network',
#  'complex system mechanical design mechanical design mechanical design',
#  'ml dl app dev english poetry prose fiction english poetry prose fiction english poetry prose fiction',
#  'machine learning business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db business domain education utility water electricity retail car manufacturing ntechnical domain system design aws azure web mobile development backend development api microservices database ai quantum computing nprogramming skillset c python react j code tool like bubble io mysql postgres mongo db',
#  'cyber security coding python awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill',
#  'ui ux design artificial intelligence research basic computer science student artificial intelligence research basic computer science student artificial intelligence research basic computer science student',
#  'iot pcb designing arduino programming basic linux data science data science data science',
#  'c machine learning machine learning machine learning',
#  'sport analysis nbasic genomics knowledge quantum computing quantum computing quantum computing',
#  'dsa frontend database database database',
#  'awareness basic knowledge social issue poverty homelessness addiction well depth study knowledge human behaviour group behaviour n nskill set empathy listening skill basic data collection analysis interpretation skill ui ui ui',
#  'business intelligence project management project management project management',
#  'data management large industry ai ml dl ai ml dl ai ml dl',
#  'dsa frontend law law law',
#  'blockchain ty ba economics student ty ba economics student ty ba economics student',
#  'sustainable computing flutter swift firebase flutter swift firebase flutter swift firebase',
#  'digital humanity drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology',
#  'python sql tableau data analytics python python python',
#  'cyber security coding python devops devops devops',
#  'data science ai ml social network analysis social network analysis social network analysis',
#  'mobile development dsa frontend dsa frontend dsa frontend',
#  'networking spacy python spacy python spacy python',
#  'augmented reality internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization',
#  'etl process cyber security coding python cyber security coding python cyber security coding python',
#  'cognitive science arduino ide ro fusion arduino ide ro fusion arduino ide ro fusion',
#  'cyber security coding python dsa frontend dsa frontend dsa frontend',
#  'computational neuroscience distributed system distributed system distributed system',
#  'skilled nlp risk analysis llm nlp risk analysis llm nlp risk analysis llm',
#  'data warehousing machine learning machine learning machine learning',
#  'bioinformatics augmented reality augmented reality augmented reality',
#  'web development nbioinformatics tool nmarketing strategy ngame design theoretical computer science theoretical computer science theoretical computer science',
#  'iot front end dev nbasic ui ux design nbasic back end knowledge front end dev nbasic ui ux design nbasic back end knowledge front end dev nbasic ui ux design nbasic back end knowledge',
#  'cyber security coding python idea know like basic everything idea know like basic everything idea know like basic everything',
#  'ty ba economics student c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd',
#  'data analysis flutter swift kotlin flutter swift kotlin flutter swift kotlin',
#  'data analysis quantum computing quantum computing quantum computing',
#  'english poetry prose fiction programming web development app development data science testing programming web development app development data science testing programming web development app development data science testing',
#  'probability combinatorics python java python c c html cs java python c c html cs java python c c html cs',
#  'matlab etl process etl process etl process',
#  'etl process database database database',
#  'spacy python parallel computing parallel computing parallel computing',
#  'excel data analytics ai tensorflow data analytics ai tensorflow data analytics ai tensorflow',
#  'html quantum computing quantum computing quantum computing',
#  'health informatics arduino ide ro fusion arduino ide ro fusion arduino ide ro fusion',
#  'system administration data analysis data analysis data analysis',
#  'cyber security coding python iot iot iot',
#  'mechanical design mobile development mobile development mobile development',
#  'system administration android developer android developer android developer',
#  'algorithm ml dl app dev ml dl app dev ml dl app dev',
#  'complex system mainly necessary coding language web development mainly necessary coding language web development mainly necessary coding language web development',
#  'machine learning e commerce technology e commerce technology e commerce technology',
#  'data mining c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd',
#  'ml data analysis agile methodology agile methodology agile methodology',
#  'nada robotics robotics robotics',
#  'iot cloud computing cloud computing cloud computing',
#  'mern stack spring boot java python sql tableau data analytics python sql tableau data analytics python sql tableau data analytics',
#  'parallel computing project management project management project management',
#  'machine learning neural network enterpreneurship communication web development web development web development',
#  'structural analysis smart smart smart',
#  'data mining excel excel excel',
#  'ml dl app dev sustainable computing sustainable computing sustainable computing',
#  'virtual reality software engineering software engineering software engineering',
#  'quantum computing flask data science flask data science flask data science',
#  'nlp risk analysis llm sql sql sql',
#  'r database database database',
#  'verilog coding arduino coding coding natural language processing natural language processing natural language processing',
#  'human computer interaction verilog coding arduino coding coding verilog coding arduino coding coding verilog coding arduino coding coding',
#  'ai ml c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd',
#  'html mainly necessary coding language web development mainly necessary coding language web development mainly necessary coding language web development',
#  'ml dl app dev html cs j ml html cs j ml html cs j ml',
#  'robotics cs cs cs',
#  'web development nbioinformatics tool nmarketing strategy ngame design digital design nformal verification digital design nformal verification digital design nformal verification',
#  'algorithm health informatics health informatics health informatics',
#  'quantum computing expert expert expert',
#  'big data escape escape escape',
#  'sql arduino ide ro fusion arduino ide ro fusion arduino ide ro fusion',
#  'computational neuroscience expert expert expert',
#  'ty ba economics student flutter swift kotlin flutter swift kotlin flutter swift kotlin',
#  'information retrieval tanner tool vivado matlab python etc tanner tool vivado matlab python etc tanner tool vivado matlab python etc',
#  'internship experience vapt project work python javascript framework research experience malware analysis open source contribution international organization iot pcb designing arduino programming basic linux iot pcb designing arduino programming basic linux iot pcb designing arduino programming basic linux',
#  'expert accounting finance commerce basic computer application accounting finance commerce basic computer application accounting finance commerce basic computer application',
#  'cognitive science etl process etl process etl process',
#  'nada bioinformatics bioinformatics bioinformatics',
#  'digital humanity iot pcb designing arduino programming basic linux iot pcb designing arduino programming basic linux iot pcb designing arduino programming basic linux',
#  'theoretical computer science parallel computing parallel computing parallel computing',
#  'drug development bioinformatics r programming molecular biology research methodology cell culture upstream downstream process technology smart smart smart',
#  'html reactjs dl ml dl app dev ml dl app dev ml dl app dev',
#  'web development nbioinformatics tool nmarketing strategy ngame design c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd',
#  'software testing c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd c c python java html cs sql aws figma flutterflow canva adobe xd',
#  'human computer interaction digital design nformal verification digital design nformal verification digital design nformal verification']

# %% [markdown]
# ## Combining maintaing index positions

# %%
df_preprocessed = pd.DataFrame({
    'Skills': Skills_preprocessed,
    'Topic': Topic_preprocessed
})

# %%
df_preprocessed['Combined'] = df_preprocessed['Skills'] + ', ' + df_preprocessed['Topic']

# Drop the individual columns if you only need the combined column
df_combined = df_preprocessed.drop(columns=['Skills', 'Topic'])

# %%
df_combined
# Out:
#                                               Combined
# 0                       structural analysis, structure
# 1    mainly necessary coding language web developme...
# 2                    data analytics ai tensorflow, nlp
# 3             english poetry prose fiction, literature
# 4                   mechanical design, data management
# ..                                                 ...
# 572  drug development bioinformatics r programming ...
# 573  html reactjs dl ml dl app dev ml dl app dev ml...
# 574  web development nbioinformatics tool nmarketin...
# 575  software testing c c python java html cs sql a...
# 576  human computer interaction digital design nfor...
#
# [577 rows x 1 columns]

# %% [markdown]
# ## BERT - large uncased

# %%
from transformers import BertTokenizer, BertModel
import torch

tokenizer = BertTokenizer.from_pretrained('bert-large-uncased')  # You can change this to other BERT models
model = BertModel.from_pretrained('bert-large-uncased')

# %%
def get_embeddings(texts):
    embeddings = []
    for text in texts:
        inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512)
        with torch.no_grad():
            outputs = model(**inputs)
        # Use the mean of token embeddings as the sentence embedding
        sentence_embedding = outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
        embeddings.append(sentence_embedding)
    return embeddings

# %%
embeddings = get_embeddings(df_combined['Combined'].tolist())

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute the cosine similarity matrix
cosine_sim_matrix = cosine_similarity(embeddings)

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df_combined['Combined'])

# %%
from sklearn.preprocessing import normalize

tfidf_embeddings = normalize(tfidf_matrix)
bert_embeddings = normalize(embeddings)

# %%
import numpy as np

# Convert sparse matrices to dense
tfidf_dense = tfidf_matrix.toarray()  # Assuming tfidf_matrix is a sparse matrix
bert_dense = np.array(bert_embeddings)  # Ensure bert_embeddings is a dense numpy array

# Perform operations on dense arrays
combined_embeddings = np.concatenate((tfidf_dense, bert_dense), axis=1)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute the cosine similarity matrix
cosine_sim_matrix = cosine_similarity(combined_embeddings)

# %%
from sklearn.cluster import AffinityPropagation
# Step 3: Apply Affinity Propagation
affinity_propagation = AffinityPropagation(affinity='precomputed', random_state=42)
labels = affinity_propagation.fit_predict(cosine_sim_matrix)

# Step 4: Create a DataFrame to view results
df = pd.DataFrame({'Skillset': df_combined['Combined'], 'Cluster': labels})

# Print the DataFrame with clusters
print("Clustered Skillsets with Affinity Propagation:")
print(df)

# Print the number of items in each cluster
cluster_counts = df['Cluster'].value_counts().sort_index()
print("\nNumber of Items in Each Cluster:")
print(cluster_counts)
# Out:
# Clustered Skillsets with Affinity Propagation:
#                                               Skillset  Cluster
# 0                       structural analysis, structure        4
# 1    mainly necessary coding language web developme...      103
# 2                    data analytics ai tensorflow, nlp       39
# 3             english poetry prose fiction, literature        3
# 4                   mechanical design, data management       26
# ..                                                 ...      ...
# 572  drug development bioinformatics r programming ...       95
# 573  html reactjs dl ml dl app dev ml dl app dev ml...      100
# 574  web development nbioinformatics tool nmarketin...      102
# 575  software testing c c python java html cs sql a...      102
# 576  human computer interaction digital design nfor...       62
#
# [577 rows x 2 columns]
#
# Number of Items in Each Cluster:
# Cluster
# 0       2
# 1       2
# 2      11
# 3       4
# 4       3
#        ..
# 101     4
# 102     7
# 103     6
# 104     5
# 105     8
# Name: count, Length: 106, dtype: int64

# %%
#Printing the number of data in each cluster
cluster_counts = df['Cluster'].value_counts().sort_index()
print("\nNumber of Items in Each Cluster:")
print(cluster_counts)
# Out:
# Number of Items in Each Cluster:
# Cluster
# 0       2
# 1       2
# 2      11
# 3       4
# 4       3
#        ..
# 101     4
# 102     7
# 103     6
# 104     5
# 105     8
# Name: count, Length: 106, dtype: int64

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

tsne = TSNE(n_components=2, random_state=42, perplexity=30)
reduced_matrix = tsne.fit_transform(tfidf_matrix.toarray())

# Add t-SNE results to DataFrame
df_tsne = pd.DataFrame(reduced_matrix, columns=['TSNE1', 'TSNE2'])
df_tsne['Cluster'] = labels

# Plot the clusters
plt.figure(figsize=(12, 8))
sns.scatterplot(x='TSNE1', y='TSNE2', hue='Cluster', data=df_tsne, palette='viridis', marker='o', s=100)
plt.title('Clusters Visualized with t-SNE')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(title='Cluster')
plt.savefig('hybrid_cluster.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
cluster_df = df[df['Cluster'] == 56]

# %%
cluster_df
# Out:
#                                               Skillset  Cluster
# 6    machine learning neural network enterpreneursh...       56
# 91   sql machine learning neural network enterprene...       56
# 120  cybersecurity machine learning neural network ...       56
# 312  game theory machine learning neural network en...       56
# 441  robotics machine learning neural network enter...       56
# 456  machine learning neural network enterpreneursh...       56

# %% [markdown]
# ## Intra-cluster similairty

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Initialize a list to hold intra-cluster similarities
intra_cluster_similarities = []

# Get unique cluster labels
unique_clusters = np.unique(labels)

for cluster in unique_clusters:
    # Get the indices of the data points in the current cluster
    cluster_indices = np.where(labels == cluster)[0]
    
    if len(cluster_indices) > 1:  # Only compute if more than one point
        # Extract the embeddings for the current cluster
        cluster_embeddings = combined_embeddings[cluster_indices]

        # Compute the cosine similarity matrix for the current cluster
        cluster_sim_matrix = cosine_similarity(cluster_embeddings)
        
        # Get the number of points in the cluster
        num_points = len(cluster_indices)
        
        # Compute the average similarity within the cluster
        # Exclude the diagonal (self-similarity) from the average
        avg_similarity = (np.sum(cluster_sim_matrix) - num_points) / (num_points * (num_points - 1))
        
        intra_cluster_similarities.append(avg_similarity)
    else:
        # Not enough points to calculate
        intra_cluster_similarities.append(np.nan)

# Calculate the overall intra-cluster similarity
# Filter out NaN values (clusters with only one point)
valid_similarities = [sim for sim in intra_cluster_similarities if not np.isnan(sim)]
overall_intra_cluster_similarity = np.mean(valid_similarities) if valid_similarities else np.nan

# Print the overall intra-cluster similarity
print(f"Overall Intra-Cluster Similarity: {overall_intra_cluster_similarity:.4f}")
# Out:
# Overall Intra-Cluster Similarity: 0.8053

# %%
from sklearn.metrics import silhouette_score

# Assuming `embeddings` is your feature matrix and `labels` are your cluster labels
silhouette_avg = silhouette_score(combined_embeddings, labels)

# Print the Silhouette Score
print(f"Silhouette Score: {silhouette_avg:.4f}")
# Out:
# Silhouette Score: 0.3383

# %%
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.metrics import davies_bouldin_score

# Compute the Davies-Bouldin Index
dbi = davies_bouldin_score(combined_embeddings, labels)

# Print the Davies-Bouldin Index
print(f"Davies-Bouldin Index: {dbi:.4f}")
# Out:
# Davies-Bouldin Index: 1.1052

# %%
data['Combined'] = df['Skillset']
data['Cluster']=df['Cluster']

# %%
data
# Out:
#                    Name                            Email  profession  \
# 0             Deependar            deependar37@gmail.com     Student
# 1         Devanshi Vora           devanshi.v11@gmail.com     Student
# 2            Hamsini .R        hamsini.ramanan@gmail.com     Student
# 3                 Zenha             zenhaiqbal@gmail.com     Student
# 4                 Jothi            jothithangu@gmail.com     Faculty
# ..                  ...                              ...         ...
# 572         Tyler Rojas       tyler.rojas@university.edu  Researcher
# 573        Sierra Zhang      sierra.zhang@university.edu     Faculty
# 574       Joshua Hughes     joshua.hughes@university.edu  Researcher
# 575     Jeffery Hammond      jeffery.hammond@example.com     Student
# 576  Christopher Wagner  christopher.wagner@research.org     Faculty
#
#                interest                 collaboration  \
# 0              Projects              Student, Faculty
# 1              Projects  Student, Faculty, Researcher
# 2    Projects, Research  Student, Faculty, Researcher
# 3          Study Groups                       Student
# 4              Projects                       Faculty
# ..                  ...                           ...
# 572            Projects                    Researcher
# 573        Study groups                    Researcher
# 574            Projects                    Researcher
# 575            Projects                       Student
# 576        Study groups                       Student
#
#                           Topic  \
# 0                    Structures
# 1                       AI & ML
# 2                           NLP
# 3                    Literature
# 4               Data management
# ..                          ...
# 572        Robotics and Sensors
# 573  Human-Computer Interaction
# 574       Sustainable Computing
# 575               Cybersecurity
# 576     Artificial Intelligence
#
#                                                 Skills  Experience  \
# 0                                 Structural analysis.         3.0
# 1    Mainly necessary coding languages and web deve...         3.0
# 2                     Data Analytics , AI , Tensorflow         4.0
# 3                       English poetry, prose, fiction         5.0
# 4                                    Mechanical Design        12.0
# ..                                                 ...         ...
# 572  Drug development, bioinformatics with R progra...         3.0
# 573  HTML,ReactJS, DL, ml, dl, app dev, ml, dl, app...        18.0
# 574  Web development\nBioinformatics tools\nMarketi...         5.0
# 575  Software Testing, C, C++, Python, Java, HTML, ...         1.0
# 576  Human-Computer Interaction, Digital design\nFo...        11.0
#
#                                               Combined  Cluster
# 0                       structural analysis, structure        4
# 1    mainly necessary coding language web developme...      103
# 2                    data analytics ai tensorflow, nlp       39
# 3             english poetry prose fiction, literature        3
# 4                   mechanical design, data management       26
# ..                                                 ...      ...
# 572  drug development bioinformatics r programming ...       95
# 573  html reactjs dl ml dl app dev ml dl app dev ml...      100
# 574  web development nbioinformatics tool nmarketin...      102
# 575  software testing c c python java html cs sql a...      102
# 576  human computer interaction digital design nfor...       62
#
# [577 rows x 10 columns]

# %% [markdown]
# ## Recommendation function

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def recommend_profiles_by_topic_skills(user_index, df, top_n=5):
    """
    Recommends the top N profiles to a target profile based on 'Topic' and 'Skills' columns.

    Parameters:
    - user_index (int): The index of the target profile in the DataFrame.
    - df (pandas.DataFrame): The DataFrame containing profile data.
    - top_n (int): The number of top profiles to recommend.

    Returns:
    - list of tuples: Each tuple contains the index and similarity score of a recommended profile.
    """
    
    
    # Get the TF-IDF vector for the target profile
    target_vector = combined_embeddings[user_index].reshape(1, -1)
    
    # Compute cosine similarities between the target profile and all other profiles
    similarities = cosine_similarity(target_vector, combined_embeddings).flatten()
    
    # Exclude the target profile itself by setting its similarity score to -1
    similarities[user_index] = -1
    
    # Get the indices of the top N most similar profiles
    top_indices = similarities.argsort()[-top_n:][::-1]
    
    # Create a list of tuples with index and similarity score
    recommendations = [(idx, similarities[idx]) for idx in top_indices]
    
    return recommendations

def print_profile_details(profile_index, df):
    """
    Prints the details of a specific profile.

    Parameters:
    - profile_index (int): The index of the profile in the DataFrame.
    - df (pandas.DataFrame): The DataFrame containing profile data.
    """
    profile_details = df.iloc[profile_index]
    print(f"Details of Target Profile (Index: {profile_index}):")
    print(f"Name: {profile_details['Name']}")
    print(f"Email: {profile_details['Email']}")
    print(f"Skills: {profile_details['Skills']}")
    print(f"Domain Interest: {profile_details['Topic']}")
    print(f"Cluster: {profile_details['Cluster']}")
    print("-" * 40)


def print_recommendation_details(recommendations, df):
    """
    Prints the details of the recommended profiles.

    Parameters:
    - recommendations (list of tuples): Each tuple contains the index and similarity score of a recommended profile.
    - df (pandas.DataFrame): The DataFrame containing profile data.
    """
    for idx, score in recommendations:
        profile_details = data.iloc[idx]
        print(f"Index: {idx}")
        print(f"Similarity Score: {score:.4f}")
        print(f"Name: {profile_details['Name']}")
        print(f"Email: {profile_details['Email']}")
        print(f"Skills: {profile_details['Skills']}")
        print(f"Domain Interest: {profile_details['Topic']}")
        print(f"Cluster: {profile_details['Cluster']}")
        print("-" * 40)
        
target_profile_index = 575  # Replace with the index of the target profile
print_profile_details(target_profile_index, data)
top_n_recommendations = recommend_profiles_by_topic_skills(target_profile_index, data, top_n=5)
print_recommendation_details(top_n_recommendations, data)
# Out:
# Details of Target Profile (Index: 575):
# Name: Jeffery Hammond
# Email: jeffery.hammond@example.com
# Skills: Software Testing, C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD.
# Domain Interest: Cybersecurity
# Cluster: 102
# ----------------------------------------
# Index: 554
# Similarity Score: 0.9833
# Name: Joan Evans
# Email: joan.evans@university.edu
# Skills: ai ml, C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD.
# Domain Interest: nlp
# Cluster: 102
# ----------------------------------------
# Index: 538
# Similarity Score: 0.9804
# Name: Gregory Williamson
# Email: gregory.williamson@example.com
# Skills: Data Mining, C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD.
# Domain Interest: Database Management
# Cluster: 102
# ----------------------------------------
# Index: 520
# Similarity Score: 0.9709
# Name: Alexis Moore
# Email: alexis.moore@example.com
# Skills: i am a ty ba economics student, C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD.
# Domain Interest: System Administration
# Cluster: 102
# ----------------------------------------
# Index: 574
# Similarity Score: 0.9643
# Name: Joshua Hughes
# Email: joshua.hughes@university.edu
# Skills: Web development\nBioinformatics tools\nMarketing strategies\nGame design, C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD., C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD.
# Domain Interest: Sustainable Computing
# Cluster: 102
# ----------------------------------------
# Index: 33
# Similarity Score: 0.8543
# Name: Srinidhi Arunkumar
# Email: srinidhi.arunkumar2021@vitsudent.ac.in
# Skills: C, C++, Python, Java, HTML, CSS, SQL, AWS, Figma , FlutterFlow, Canva, Adobe XD.
# Domain Interest: AWS , UI/UX DESIGN
# Cluster: 102
# ----------------------------------------
